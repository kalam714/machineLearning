# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
car = pd.read_csv('car.csv')
# %matplotlib inline

# %%
car.head()
car.shape
# Out:
# (398, 9)

# %%
car.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
car["cylinders"].unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
sns.distplot(car['cylinders'], bins=6)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cylinders', ylabel='Density'>

# %%
sns.distplot(car['cylinders'], bins=range(3,10,1))
plt.xticks(range(3,9,1))
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ([<matplotlib.axis.XTick at 0x203a01b4f40>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
sns.distplot(car["cylinders"], kde=False, bins=range(3,10,1))
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cylinders'>

# %%
sns.distplot(car["cylinders"], hist=False, bins=range(3,10,1))
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cylinders', ylabel='Density'>

# %%
# sns.catplot(x='cylinders',kind='count',data=car)
sns.countplot(x = 'cylinders', data=car)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='count'>

# %%
sns.catplot(x='cylinders',kind='count',data=car,color='blue')

# %%
car["origin"].unique()
# Out:
# array([1, 3, 2], dtype=int64)

# %%
sns.countplot(x = 'cylinders', data=car, color='blue', hue='origin')
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='count'>

# %%
sns.countplot(x = 'cylinders', data=car, color='red', hue='origin')
plt.legend(loc = 'lower right')

# %%
sns.boxplot(y='acceleration', data=car)
plt.xlabel('Acceleration')
# Out:
# Text(0.5, 0, 'Acceleration')

# %%
sns.boxplot(y='acceleration',x='origin', data=car)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='acceleration'>

# %%
sns.boxplot(y='acceleration',x='cylinders', data=car)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='acceleration'>

# %%
sns.jointplot(x='horsepower',y='acceleration', data=car)

# %%
sns.scatterplot(x='horsepower',y='acceleration', data=car)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='acceleration'>

# %%
sns.scatterplot(y='acceleration',x='horsepower', data=car, alpha=0.2)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='acceleration'>

# %%
sns.scatterplot(y='acceleration',x='horsepower', hue='origin', data=car)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='acceleration'>

# %%
plt.subplot(2,2,1)
sns.scatterplot(y='acceleration',x='horsepower', hue='origin', data=car)

plt.subplot(2,2,2)
sns.scatterplot(y='acceleration',x='horsepower', data=car, alpha=0.2)

plt.subplot(2,2,3)
sns.boxplot(y='acceleration',x='origin', data=car)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='acceleration'>

# %%
plt.subplot(2,2,1)
sns.scatterplot(y='acceleration',x='horsepower', hue='origin', data=car)

plt.subplot(2,2,2)
sns.scatterplot(y='acceleration',x='horsepower', data=car, alpha=0.2)

plt.subplot(2,2,3)
sns.boxplot(y='acceleration',x='origin', data=car)
plt.figure(figsize=(10,10))

# %%
# plt.subplot(2,2,1)
# sns.scatterplot(y='acceleration',x='horsepower', hue='origin', data=car)

# plt.subplot(2,2,2)
# sns.scatterplot(y='acceleration',x='horsepower', data=car, alpha=0.2)

# plt.subplot(2,2,3)
# sns.boxplot(y='acceleration',x='origin', data=car)
# plt.figure(figsize=(10,10))
# plt.savefig('plot.png')

# %%
sns.lmplot(x='cylinders', y='acceleration', data=car)

# %%
sns.lmplot(x='cylinders', y='acceleration',col='origin', data=car)

# %%
sns.lmplot(x='cylinders', y='acceleration',row='origin', data=car)
